# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjananallapati/Satellite-Imagery-Based-Property-Valuation-/blob/main/preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.listdir()
# Out:
# ['.config', 'train(1).xlsx', 'test2.xlsx', 'sample_data']

# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_excel('train(1).xlsx')
test_df=pd.read_excel('test2.xlsx')

# %%
print("Train shape:", train_df.shape)
print("Test shape :", test_df.shape)
# Out:
# Train shape: (16209, 21)
# Test shape : (5404, 20)

# %%
print("Train columns:\n", train_df.columns)
print("Test columns:\n", test_df.columns)
# Out:
# Train columns:
#  Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')
# Test columns:
#  Index(['id', 'date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
train_df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  9117000170  20150505T000000  268643         4       2.25         1810
# 1  6700390210  20140708T000000  245000         3       2.50         1600
# 2  7212660540  20150115T000000  200000         4       2.50         1720
# 3  8562780200  20150427T000000  352499         2       2.25         1240
# 4  7760400350  20141205T000000  232000         3       2.00         1280
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      9240     2.0           0     0  ...      7        1810              0
# 1      2788     2.0           0     0  ...      7        1600              0
# 2      8638     2.0           0     0  ...      8        1720              0
# 3       705     2.0           0     0  ...      7        1150             90
# 4     13356     1.0           0     0  ...      7        1280              0
#
# ...

# %%
print("missing values in train")
print(train_df.isnull().sum())
# Out:
# missing values in train
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
print("missing values in test")
print(test_df.isnull().sum())
# Out:
# missing values in test
# id               0
# date             0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6,4))
plt.hist(train_df['price'], bins=50)
plt.xlabel('Price')
plt.ylabel('Number of Houses')
plt.title('Distribution of House Prices')
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.scatter(train_df['sqft_living'], train_df['price'], alpha=0.5)
plt.xlabel('Living Area in sqft')
plt.ylabel('Price')
plt.title('Price vs Living Area')
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.histplot(np.log1p(train_df["price"]), bins=50, kde=True)
plt.title("Log-Transformed House Price Distribution")
plt.xlabel("log(price)")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(train_df["long"], train_df["lat"], c=np.log1p(train_df["price"]),
            cmap="viridis", s=5)
plt.colorbar(label="log(price)")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Geospatial Distribution of House Prices")
plt.show()
